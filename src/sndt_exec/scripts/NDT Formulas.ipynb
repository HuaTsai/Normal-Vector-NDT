# %% [markdown]
# # NDT Formulas
#
# This document is mainly for deriving objective functions of NDT and its variants.
#
# The following methods will be covered in this document.
#
# 1. Point-to-distribution NDT
# 2. Distribution-to-distribution NDT
# 3. Normal + Distribution-to-distribution NDT

# %% [markdown]
# ## Point-to-Distribution NDT
#
# ![p2d-ndt.png](attachment:p2d-ndt.png)
#
# ### Derivation

# %%
import sympy as sym
