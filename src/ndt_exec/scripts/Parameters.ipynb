# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
# %matplotlib inline

sicp = [9.102379, 7.368649]
x = 10 ** np.arange(-0.2, -2.1, -0.1)
ndt = np.array([
#     [20.541557, 11.301790],
#     [11.1426, 5.96814],
    [5.58664, 3.14427],
    [3.22291, 1.972],
    [2.7108, 1.7856],
    [2.24455, 1.46312],
    [2.29688, 1.37604],
    [2.47795, 1.44807],
    [2.48896, 1.415],
    [2.71173, 1.37292],
    [2.80442, 1.38456],
    [2.92511, 1.38952],
    [3.12485, 1.51666],
    [3.39196, 1.55962],
    [3.6099, 1.6844],
    [3.91863, 1.74183],
    [4.1763, 1.8103],
    [4.47813, 1.87649],
    [5.03172, 2.03584],
    [5.35735, 2.19718],
    [5.54989, 2.3325],
])
sndt = np.array([
#     [3.283250, 1.975999],
#     [3.12552, 1.92644],
    [3.04874, 1.82877],
    [2.7939, 1.51552],
    [2.51141, 1.35728],
    [2.50614, 1.38212],
    [2.61595, 1.41162],
    [2.76198, 1.48642],
    [2.83288, 1.42453],
    [2.95585, 1.44703],
    [3.11169, 1.51823],
    [3.27671, 1.59214],
    [3.45174, 1.60607],
    [3.68961, 1.70671],
    [3.84722, 1.74821],
    [3.99952, 1.73874],
    [4.40715, 1.76436],
    [4.68924, 1.8122],
    [5.04768, 2.02834],
    [5.50609, 2.15828],
    [5.8276, 2.27163]
])

fig = plt.figure(figsize=(14, 6))
ax = fig.add_subplot(121)
ax.invert_xaxis()
ax.set_xlabel('$d_2$')
ax.set_ylabel('Translation Relative Pose Error (RMS) [m/100m]')
ax.axhline(sicp[0], label='SICP', c='b')
ax.axhline(6.07579, label='NDT-MD + Reject', c='r')
ax.axhline(7.61877, label='SNDT-MD + Reject', c='g')
ax.plot(x, sndt[:,0], label='SNDT')
ax.plot(x, ndt[:,0], label='NDT')
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.legend(fontsize=12, loc='upper right')

ax = fig.add_subplot(122)
ax.invert_xaxis()
ax.set_xlabel('$d_2$')
ax.set_ylabel('Rotation Relative Pose Error (RMS) [deg/100m]')
ax.axhline(sicp[1], label='SICP', c='b')
ax.axhline(5.37127, label='NDT-MD + Reject', c='r')
ax.axhline(6.38607, label='SNDT-MD + Reject', c='g')
ax.plot(x, sndt[:,1], label='SNDT')
ax.plot(x, ndt[:,1], label='NDT')
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.legend(fontsize=12, loc='upper right')
